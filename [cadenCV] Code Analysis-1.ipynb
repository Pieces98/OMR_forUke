# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

import util_functions as fs
import imp
imp.reload(fs)

# %matplotlib inline

# %%
img = fs.get_images('./data/Tab_Butterfly-Waltz-Ukulele/p1.jpg', 0.5, 200)
# Out:
# >>> File : ./data/Tab_Butterfly-Waltz-Ukulele/p1.jpg
# 01 : ./data/Tab_Butterfly-Waltz-Ukulele/p1.jpg : (2339, 1653)
# >>> Resize factor : x0.5 : (2339, 1653)->(1170, 826)
# >>> Inverse binary thresholding with threshold value 200

# %%
fs.plot_single_image(img)

# %%
img_rows, img_cols = img.shape
